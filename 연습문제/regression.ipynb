# %% [markdown]
# 🟨 AICE Associate 실전 연습문제 - 회귀 문제 Set (Regression, 총 14문항)
# 📘 시나리오
# 운행 거리, 속도, 출발 시간대 및 지역 등의 정보를 이용하여 Time_Driving을 예측하는 회귀 모델을 구축합니다.
#
# 문제 1
# 데이터를 불러오고 첫 5행을 출력하세요.
# 파일명: A0007IT.json

# %% [markdown]
# 문제 2
# Time_Driving 또는 Distance에 결측치가 있는 행을 제거한 DataFrame을 생성하세요.

# %% [markdown]
# 문제 3
# avg_speed (km/h) 컬럼을 생성하세요.
#
# 계산식: Distance / Time_Driving * 3.6

# %% [markdown]
# 문제 4
# 범주형 컬럼 (Weekday, Address1, Address2)을 더미 변수로 변환하세요.

# %% [markdown]
# 문제 5
# 타겟: Time_Driving, 그 외는 Feature로 설정하여 X, y를 분리하세요.

# %% [markdown]
# 문제 6
# 훈련/테스트 데이터를 8:2로 분할하세요.

# %% [markdown]
# 문제 7
# RandomForestRegressor로 모델을 학습하세요.

# %% [markdown]
# 문제 8
# 검증 데이터셋에 대해 예측을 수행하세요.

# %% [markdown]
# 문제 9
# 평균 절대 오차(MAE)를 계산하세요.

# %% [markdown]
# 문제 10
# 평균 제곱근 오차(RMSE)를 계산하세요.

# %% [markdown]
# 문제 11
# R2 Score를 출력하세요.

# %% [markdown]
# 문제 12
# 예측값 vs 실제값 산점도를 시각화하세요.

# %% [markdown]
# 문제 13
# 중요 Feature 상위 10개를 시각화하세요.

# %% [markdown]
# 문제 14
# 학습된 모델을 regression_model.pkl로 저장하세요.
